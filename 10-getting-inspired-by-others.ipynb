# %% [markdown]
# I created all the previous notebooks by myself. Now I want to look at what others did, and learn how I can improve my score.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

def load_train_data(split=True):
    target = "Survived"
    data = pd.read_csv("./train.csv", index_col="PassengerId")
    print("load_train_data: done")
    
    if split:
        return split_features_target(data, target)
    else:
        return data
    
def split_features_target(df, target="Survived"):
    features = [column for column in df.columns if not column == target]
    return df[features], df[target]

def load_x_test():
    return pd.read_csv("./test.csv", index_col="PassengerId")

# %%
X_train, y_train = load_train_data()
X_test = load_x_test()
X_test_index = X_test.index


features = ["Pclass", "Sex", "SibSp", "Parch"]
X_train = pd.get_dummies(X_train[features])
X_test = pd.get_dummies(X_test[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X_train, y_train)
predictions = model.predict(X_test)

scores = cross_val_score(model, X_train, y_train)
print("Accuracy: %0.5f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

output = pd.DataFrame({'PassengerId': X_test_index, 'Survived': predictions})
output.to_csv('submissions/04-tutorial-submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# load_train_data: done
# Accuracy: 0.79914 (+/- 0.04)
# Your submission was successfully saved!

# %%
X_train
# Out:
#              Pclass  SibSp  Parch  Sex_female  Sex_male
# PassengerId
# 1                 3      1      0           0         1
# 2                 1      1      0           1         0
# 3                 3      0      0           1         0
# 4                 1      1      0           1         0
# 5                 3      0      0           0         1
# ...             ...    ...    ...         ...       ...
# 887               2      0      0           0         1
# 888               1      0      0           1         0
# 889               3      1      2           1         0
# 890               1      0      0           0         1
# 891               3      0      0           0         1
#
# [891 rows x 5 columns]
